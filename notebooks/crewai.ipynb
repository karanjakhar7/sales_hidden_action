# %%
import os
transcript_dir = r"..\transcripts"

transcripts = {}
for filename in os.listdir(transcript_dir):
    with open(os.path.join(transcript_dir, filename), 'r') as f:
        transcripts[filename.split(".")[0]] = f.read()

transcripts.keys()
# Out:
# dict_keys(['4tools', 'baselifesciences', 'bookstar', 'calmsea', 'deel', 'explorer', 'keeper', 'lasebane', 'mode', 'ss', 'stackcentral', 'xp'])

# %%
labels = {
    "4tools": """Priority: “Understand content workflow with multiple contractors so you can increase your engagement size from 10k to 20k" (see 3:07 and 8:41)
Event: “Trial expires in 8 days” (see 3:07 and 8:41)
Date: <2 weeks from now> (see 43:18)
Message: Hi Ryan, last we spoke, it was important to understand your content workflow across clients so you can scale up your engagement size to 20k. Your trial has ended. Wanted to reconnect to see if you’re ready to make a decision to proceed or not.""",
    
    "bookstar": """Priority: “Traditional outreach is failing and needs to invest in social selling but marketing is stretched thin" (see 2:40)
Event: “Kate to talk to her boss” (see 31:24)
Date: <next June> (see 38:26)
Message: Hi Kate, last we spoke, it was important to understand your content workflow across clients so you can scale up your engagement size to 20k. Your trial expires tomorrow. Wanted to reconnect to see if you’re ready to make a decision to proceed or not.""",
    
    "xp": """Priority: “Get rid of Terraform Cloud in Q3 because support is not great" (see 3:42)
Event: “TCF contracts expires” (see 31:24)
Date: <next December> (see 5:03)
Message: Hi Mike, last we spoke, it was important to move off Terraform Cloud in Q3. I know your contract ends in December. Wanted to reconnect to see if we’re on track to replace TFC.""",
    
    "mode": """Priority: “Increase thought leadership as part of ABM execution" (see 22:42)
Event: “ABM research is complete” (see 9:53)
Date: <next December> (see 5:03)
Message: Hi Swati, hope your conference in Copenhagen went well. When we last spoke, you were wrapping up the ABM account research phase. You mentioned you’d be able to enter the execution phase. Wanted to reconnect to see if you’re ready to improve Jan’s LinkedIn presence to reach key decision makers in November.""",

    }

# %%
from dotenv import load_dotenv

load_dotenv("../.env")
# Out:
# True

# %%
from crewai import Agent, Task, Crew, Process, LLM

llm = LLM(
    model = "azure/gpt-4o",
    # api_key=os.environ["OPENAI_API_KEY"],
    # base_url=os.environ["AZURE_OPENAI_ENDPOINT"],
)

# %%
call_analyzer = Agent(
  role='Senior Sales Analyst',
  goal='Uncover the hidden action items in sales calls',
  backstory="""You work as a sales person in a startup.
Your expertise lies in identifying hidden action items form the sales call.
You identify things that are not explicitly mentioned but are important next steps to the sales process.""",
  verbose=True,
  allow_delegation=False,
  llm=llm,
#   tools=[]
)
writer = Agent(
  role='Sales Messaging Specialist',
  goal='Craft a crisp message reminding the client of the action items',
  backstory="""You are a sales messaging specialist. Your expertise lies in crafting messages that are clear, concise and actionable basd on the hidden action items identified by the sales analyst.
  Only provide the action items that are more than 2 weeks away.""",
  verbose=True,
  allow_delegation=False,
  llm=llm,
)

# Create tasks for your agents
task1 = Task(
  description="""Analyze the sales call transcript and provide hidden action items, if any.
Find the action items and when to reach out to the client. Only the action items that are more than 2 weeks away are considered.

Here is the response format:
<format>
Priority: <action item in one line> (timestamp in the call, if available)
Event: <event in one line> (timestamp in the call, if available)
Date: <when to reach out to the client> (timestamp in the call, if available)
</format>

Here is a sample response:
<sample>
Priority: "Increase thought leadership as part of ABM execution" (see 22:42)
Event: "ABM research is complete" (see 9:53)
Date: <next December> (see 5:03)
</sample>

Here is the sales call transcript:
<trascript>
{sales_call_transcript}
</transcript>""",

  expected_output="""List the priority, event and date to reach out to the client in the format provided.
<sample>
Priority: "Increase thought leadership as part of ABM execution" (see 22:42)
Event: "ABM research is complete" (see 9:53)
Date: <next December> (see 5:03)
</sample>
XML tags should not be included in the response.
""",

  agent=call_analyzer
)

task2 = Task(
  description="""Using the hidden action items, craft a message to remind the client of the action items and provide the date to reach out to the client.

Here is a sample:
<sample_item>
Priority: "Increase thought leadership as part of ABM execution" (see 22:42)
Event: "ABM research is complete" (see 9:53)
Date: <next December> (see 5:03)
</sample_item>

<sample_response>
Message: Hi Swati, hope your conference in Copenhagen went well. When we last spoke, you were wrapping up the ABM account research phase. You mentioned you’d be able to enter the execution phase. Wanted to reconnect to see if you’re ready to improve Jan’s LinkedIn presence to reach key decision makers in November.
</sample_response>

""",

  expected_output="""A message for each action item to remind the client of the action items and the date to reach out to the client.
Here is the response format:
<format>
Message: <message to remind the client of the action items and the date to reach out to the client.>
</format>
XML tags should not be included in the response.
""",
  agent=writer
)

# Instantiate your crew with a sequential process
crew = Crew(
  agents=[call_analyzer, writer],
  tasks=[task1, task2],
  verbose=True,
  # process = Process.sequential
)

# %%
inputs = {
    "sales_call_transcript": transcripts["4tools"]
}

result = crew.kickoff(inputs=inputs)

# %%
print(result.tasks_output[0].raw)
print(result.tasks_output[1].raw)
# Out:
# Priority: "Explore agency-specific functionalities and needs" (see 45:01)
# Event: "Discussion on agency-side features and processes" (see 46:46)
# Date: <next evaluation period, roughly in 2 months> (see 25:31)
# Message: Hi [Client's Name], I hope you’re doing well. When we last spoke, we discussed the functionalities and needs specific to agency-side features. You mentioned you’d be open to further exploration during the next evaluation period, which is roughly in two months. Just wanted to remind you about this and check if you’re ready to revisit this discussion. Looking forward to your thoughts!

# %%
call_analyzer.verbose = False
writer.verbose = False

res = {}

for k,v in transcripts.items():
    inputs = {
        "sales_call_transcript": v
    }

    result = crew.kickoff(inputs=inputs)
    res[k] = result

# %% [markdown]
# I had asked model to find "items" ie mulitple if available, and for each task there is a message.
#
# currently it is generating more action item - some false positives, after some prompt tuning we can decrease the number of false positives

# %%
for k, v in res.items():
    print(f"{k}: ")
    print(v.tasks_output[0].raw)
    print(v.tasks_output[1].raw)
    print("\n-----------------------------------\n")
# Out:
# 4tools:
# Priority: "Evaluate the holistic view and additional agency-specific features" (see 23:59)
# Event: "Extended trial to test workflow integration" (see 41:53)
# Date: <in about 14 days> (see 43:18)
#
# Priority: "Consider integrating the AI writing tool once available" (see 32:44)
# Event: "AI writing tool release" (see 32:44)
# Date: <around 6 weeks from now> (see 32:44)
#
# Priority: "Discuss potential pricing and offerings for agencies" (see 35:24)
# Event: "Economic evaluation by floating it to a few clients" (see 38:29)
# Date: <within 2 weeks of testing> (see 43:18)
#
# Priority: "Reach out to Ryan Robinson at Close CRM" (see 44:47)
# Event: "Discussion with Ryan Robinson from Close CRM" (see 44:47)
# Date: <timeline dependent on Marc's reference> (see 43:43)
# Message: Hi [Client's name], hope you're doing well! As a quick reminder, the AI writing tool will be released around six weeks from now. Please mark your calendar for this, and let's plan to integrate the tool into your workflow once it's available. Let me know if you'd like to discuss this further.
#
# -----------------------------------
#
# baselifesciences:
# Priority: "Schedule a workshop for the policy library" (see 08:39)
# Event: "Team interest in policy library workshop confirmed" (see 08:39)
# Date: <September/October> (see 08:39)
# Message: Hi, I hope you are doing well. During our last conversation, it was confirmed that there is strong interest from the team in scheduling a workshop for the policy library. Given this, I wanted to remind you to plan for the workshop in September or October. Please let me know a convenient date for us to proceed with the arrangements. Looking forward to your response!
#
# -----------------------------------
#
# bookstar:
# Priority: "Coordinate a second call with Derek and Annie for more detailed demo and discussion" (see 38:55)
# Event: "Derek and Annie are briefed on the platform and benefits" (see 38:12)
# Date: <first week of June> (see 38:26)
# Message: Hi [Client Name], hope you're doing well! When we last spoke, you mentioned that Derek and Annie had been briefed on the platform and its benefits. As we discussed, coordinating a second call to dive into a more detailed demo and discussion would be beneficial. Let's look at scheduling this follow-up call during the first week of June. Please let me know your availability.
#
# -----------------------------------
#
# calmsea:
# Priority: "Discuss internal decision on moving forward with the agency services" (see 28:39)
# Event: "Internal discussion about agency services and platform usage" (see 28:43)
# Date: <end of next week, approximately two weeks from now> (see 28:43)
#
# Priority: "Send pricing information and follow-up materials" (see 27:48)
# Event: "Sending a screenshot of the deck with pricing information" (see 28:01)
# Date: <+ 2 days from now> (email follow-up post-call conclusion not specifically timestamped but implied through context around 28:01-29:22)
# Message: Hi [Client's Name], just a quick reminder to discuss the internal decision on moving forward with the agency services by the end of next week. Please let me know if there's anything you need from my end ahead of that discussion. Thank you!
#
# -----------------------------------
#
# deel:
# Priority: "Discuss final approval from CEO" (see 44:50)
# Event: "Meeting with CEO" (see 44:34)
# Date: <two weeks from the last conversation which was during the week of the 15th, so beginning of the first week of next month, around November 1st> (calculated from conversation timestamps)
# Message: Hi [Client's Name], hope all is well. During our last conversation in the week of the 15th, we discussed arranging a meeting with the CEO for the final approval. Considering the timeline, we should aim to follow up on this by the beginning of the first week of next month, around November 1st. Looking forward to your confirmation.
#
# -----------------------------------
#
# explorer:
# Priority: "Complete the transition to a module registry with versioning and dependency management" (see 18:28)
# Event: "Emma will conduct a deep dive into policies and documentations" (see 21:22)
# Date: <two weeks from now> (see 45:57)
#
# Priority: "Full adoption of Starlink for automated deployments" (see 01:06)
# Event: "Lyle's team to test modules on Starlink and observe the impact" (see 51:27)
# Date: <two weeks from now> (see 45:57)
#
# Priority: "Discuss details with tech lead about further Starlink integration" (see 21:06)
# Event: "Potential follow-up meeting with tech lead for a deep dive" (see 45:36)
# Date: <two weeks from now> (see 45:57)
# Message: Hi [Client's Name], hope everything is moving smoothly on your end. When we last spoke, you were preparing to conduct a deep dive into policies and documentations for the transition to a module registry with versioning and dependency management. Given that this is a high priority, I wanted to check in and see how things are progressing.
#
# Message: Hi [Client's Name], I trust things are going well for you. Lyle's team was set to begin testing modules on Starlink and observe the impact, with the goal of adopting automated deployments fully. Just wanted to follow up and see if we can touch base on the outcomes of these tests soon.
#
# Message: Hi [Client's Name], hope all is well. In our last discussion, you mentioned the need to discuss further Starlink integration in detail with your tech lead. As this is crucial for your progress, I wanted to touch base and see if you have scheduled a follow-up meeting with the tech lead to delve into these details.
#
# Looking forward to your updates!
#
# -----------------------------------
#
# keeper:
# Priority: "Get Vishal, the Webflow developer, to promise that he can achieve performance optimization on Webflow" (see 24:48)
# Event: "Once they get clarity on the migration from Ghost to Webflow" (see 28:27)
# Date: <February 28th in the morning Pacific> (see 29:19)
# Message: Hi [Client], I hope all is well with you. Following up on our earlier discussion regarding the migration from Ghost to Webflow, I wanted to remind you that it's important to get a commitment from Vishal, our Webflow developer, confirming he can achieve the required performance optimization on Webflow. Let's aim to touch base on this by February 28th in the morning Pacific time. Looking forward to your update.
#
# -----------------------------------
#
# lasebane:
# Priority: "Hire full-time SEO specialist in house" (see 18:46)
# Event: "Series A funding received" (see 18:46)
# Date: <in the next three to four months> (see 18:46)
#
# Priority: "Evaluate the use of AI for content creation and enhancement" (see 29:48)
# Event: "Set up an internal content team" (see 35:14)
# Date: <in the next six months> (see 36:00)
#
# Priority: "Explore the integration of GPT-based tools for chat interactions and customer success" (see 19:00)
# Event: "Successful trial of intercom's GPT integration" (see 19:00)
# Date: <after initial GPT integration trials> (see 19:00)
#
# Priority: "Optimize existing content for better SEO performance" (see 17:43)
# Event: "Identify content that needs refresh based on performance signals" (see 17:43)
# Date: <in the next review cycle post-series A funding>
# Message: Hi [Client's Name], congratulations again on securing your Series A funding. As per our last conversation, in the next three to four months, we should focus on hiring a full-time SEO specialist in-house to leverage this new growth phase. Let me know the best time to discuss the next steps.
#
# Message: Hi [Client's Name], I hope everything is progressing well with your internal content team setup. Given this framework, within the next six months, let's evaluate how AI can enhance your content creation efforts. Looking forward to scheduling our discussion soon.
#
# Message: Hi [Client's Name], following the successful trial of Intercom's GPT integration, we should explore further integrations of GPT-based tools for chat interactions and customer success after the initial trials are concluded. Let's sync up to plan the next phase.
#
# Message: Hi [Client's Name], with your Series A funding now in place, our next review cycle should include optimizing existing content for better SEO performance. Post-funding, we should identify content that needs refreshing based on performance signals. Let's find a convenient time to strategize this.
#
# -----------------------------------
#
# mode:
# Priority: "Schedule follow-up demo with Swati for first week of November" (see 19:00)
# Event: "User conference in October is complete" (see 26:00)
# Date: <First week of November> (see 26:00)
# Message: Hi Swati, I hope your user conference in October was a success. As we discussed earlier, it’s time to schedule the follow-up demo for the first week of November. Let me know a convenient time for you so we can proceed. Looking forward to connecting soon.
#
# -----------------------------------
#
# ss:
# Priority: "Organizing and structuring content for amplification" (see 19:36)
# Event: "Content strategy plans to be established" (see 20:07)
# Date: <21st to 25th of November> (see 21:11)
# Message: Hi [Client Name], I hope you're doing well. Just a reminder about our plan to organize and structure content for amplification. We are scheduled to establish the content strategy plans between the 21st and 25th of November. Please let me know if this timeline still works for you or if there are any adjustments needed. Looking forward to your response!
#
# -----------------------------------
#
# stackcentral:
# Priority: "Follow up on the Letterdrop trial" (see 36:15)
# Event: "Desired features of Letterdrop will be assessed during trial" (see 30:23)
# Date: <6th of January> (see 36:25)
# Message: Hi [Client's Name], I hope you are doing well. As we discussed during our last meeting, you were in the process of assessing the desired features of the Letterdrop trial. I'd like to follow up on this and will reach out to you again on the 6th of January to discuss your findings and next steps.
#
# -----------------------------------
#
# xp:
# Priority: "Ensure NDA is in place" (see 00:50)
# Event: "Legal team reviews NDA" (see 08:20)
# Date: <in about a month> (see 03:57)
#
# Priority: "Assess POC success criteria" (see 01:17)
# Event: "Mike and team review document" (see 03:33)
# Date: <after POC kickoff next week> (see 03:22)
#
# Priority: "Plan for replacement of Terraform Cloud" (see 05:20)
# Event: "Stakeholders buy-in and approval" (see 04:05)
# Date: <by end of December> (see 05:03)
# Message: Hi [Client's Name], hope all is well. This is a friendly reminder regarding a few upcoming tasks. Firstly, ensuring the NDA is in place following the legal team's review, which is slated for completion in about a month. Additionally, we need to assess the POC success criteria right after the POC kickoff, scheduled for next week. Lastly, please keep in mind the planning for the replacement of Terraform Cloud, with stakeholder buy-in and approval expected by the end of December. Looking forward to your updates and next steps.
#
# -----------------------------------
